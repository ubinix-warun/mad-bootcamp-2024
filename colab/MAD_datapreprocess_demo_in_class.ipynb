# %% [markdown]
# <a href="https://colab.research.google.com/github/ubinix-warun/mad-bootcamp-2024/blob/main/colab/MAD_datapreprocess_demo_in_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import / Read data

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date
import calendar
from dateutil.relativedelta import relativedelta

# %%
import sys
if sys.version_info[0] < 3:
    from StringIO import StringIO
else:
    from io import StringIO

# %%
pd.options.display.max_columns=100

# %%
demo_str = """user_id,income,age,tenure,province,segment,pos_dt
1,35000.0,30,3,Bangkok,middle,2023-04-01
2,100000.0,28,7,Bangkok,affluent,2023-04-01
3,50000.0,50,15,Nonthaburi,middle,2023-04-01
4,15000.0,52,18,,low,2023-04-01
5,,21,2,Phuket,affluent,2023-04-01
1,35000.0,30,3,Bangkok,middle,2023-05-01
2,100000.0,28,7,Bangkok,affluent,2023-05-01
3,50000.0,50,15,Nonthaburi,middle,2023-05-01
4,15000.0,52,18,,low,2023-05-01
5,,21,2,Phuket,affluent,2023-05-01
1,35000.0,30,3,Bangkok,middle,2023-06-01
2,100000.0,28,7,Bangkok,affluent,2023-06-01
3,50000.0,50,15,Nonthaburi,middle,2023-06-01
4,15000.0,52,18,,low,2023-06-01
5,,21,2,Phuket,affluent,2023-06-01
1,35000.0,30,3,Bangkok,middle,2023-07-01
2,100000.0,28,7,Bangkok,affluent,2023-07-01
3,50000.0,50,15,Nonthaburi,middle,2023-07-01
4,15000.0,52,18,,low,2023-07-01
5,,21,2,Phuket,affluent,2023-07-01
1,35000.0,30,3,Bangkok,middle,2023-08-01
2,100000.0,28,7,Bangkok,affluent,2023-08-01
3,50000.0,50,15,Nonthaburi,middle,2023-08-01
4,15000.0,52,18,,low,2023-08-01
5,,21,2,Phuket,affluent,2023-08-01
1,35000.0,30,3,Bangkok,middle,2023-09-01
2,100000.0,28,7,Bangkok,affluent,2023-09-01
3,50000.0,50,15,Nonthaburi,middle,2023-09-01
4,15000.0,52,18,,low,2023-09-01
5,,21,2,Phuket,affluent,2023-09-01
1,35000.0,30,3,Bangkok,middle,2023-10-01
2,100000.0,28,7,Bangkok,affluent,2023-10-01
3,50000.0,50,15,Nonthaburi,middle,2023-10-01
4,15000.0,52,18,,low,2023-10-01
5,,21,2,Phuket,affluent,2023-10-01
1,35000.0,30,3,Bangkok,middle,2023-11-01
2,100000.0,28,7,Bangkok,affluent,2023-11-01
3,50000.0,50,15,Nonthaburi,middle,2023-11-01
4,15000.0,52,18,,low,2023-11-01
5,,21,2,Phuket,affluent,2023-11-01
1,35000.0,30,3,Bangkok,middle,2023-12-01
2,100000.0,28,7,Bangkok,affluent,2023-12-01
3,50000.0,50,15,Nonthaburi,middle,2023-12-01
4,15000.0,52,18,,low,2023-12-01
5,,21,2,Phuket,affluent,2023-12-01
1,35000.0,30,3,Bangkok,middle,2024-01-01
2,100000.0,28,7,Bangkok,affluent,2024-01-01
3,50000.0,50,15,Nonthaburi,middle,2024-01-01
4,15000.0,52,18,,low,2024-01-01
5,,21,2,Phuket,affluent,2024-01-01
1,35000.0,30,3,Bangkok,middle,2024-02-01
2,100000.0,28,7,Bangkok,affluent,2024-02-01
4,2023-08-05,77.83298860203723,gasoline
5,2024-02-19,9162.910342525342,gasoline
2,2024-01-23,4428.459523388037,gasoline
5,2024-01-15,6494.352745407852,other
4,2023-10-07,1805.3087094840932,other
3,2023-11-21,4265.034088640441,food
5,2023-10-04,682.1932798151507,food
4,2023-12-08,264.43911718859215,other
5,2023-10-01,4903.033258120514,other
4,2024-01-11,957.6322966051816,gasoline
4,2023-09-05,383.7918304295567,gasoline
3,2024-01-27,6255.764897698002,food
2,2023-12-19,420.44740710498695,brandname
4,2024-01-08,1270.5480986726318,brandname
4,2023-11-18,1253.0687922311192,other
5,2024-02-10,13448.594806802106,food
3,2023-08-01,236.5015078654997,food
4,2024-01-19,330.24947554689913,food
5,2023-11-20,19251.937211892244,brandname
5,2023-08-13,351.70505658828256,other
3,2023-09-24,3205.3771208747485,food
1,2023-10-19,2314.141455640886,gasoline
4,2023-08-05,303.5906989926956,food
1,2023-08-11,2429.128601366146,gasoline
5,2023-10-07,7886.957395548937,food
2,2023-12-07,1998.7811781362673,other
5,2023-10-11,13738.203678083251,other
3,2024-02-26,3473.0074746990713,gasoline
3,2023-10-20,104.0667277670474,gasoline
4,2024-01-03,35.05457423846665,other
2,2023-10-24,1501.1084021557235,gasoline
2,2023-10-27,1960.3204984416968,food
4,2024-01-03,808.1107470892284,brandname
2,2023-12-27,1601.5317900992077,gasoline
4,2024-02-19,1137.0724849181515,gasoline
5,2023-10-11,6590.216165074564,brandname
3,2024-02-06,3582.1706872922464,gasoline
5,2024-01-13,3952.165505470351,other
1,2023-10-20,2443.2863691627094,brandname
4,2024-02-24,915.7775238807913,food
3,2023-11-10,3551.5938997323733,gasoline
4,2023-10-21,228.30544426634208,brandname
1,2023-09-13,125.42350701285449,other
3,2024-02-21,5420.344182633524,brandname
5,2023-11-02,3576.090754004136,gasoline
"""

# %%
cc_txn_csv = StringIO(credit_str)
demo_csv = StringIO(demo_str)

# %% [markdown]
# # Dataset

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date
import calendar
from dateutil.relativedelta import relativedelta

demo = pd.read_csv(demo_csv)
cc_txn = pd.read_csv(cc_txn_csv)
demo['pos_dt'] = pd.to_datetime(demo['pos_dt'])
cc_txn['pos_dt'] = pd.to_datetime(cc_txn['pos_dt'])

# %% [markdown]
# # Our goal

# %%
def pipeline_features(demo, cc_txn, cohort):
    """......"""
    return X

def pipeline_label(demo, cc_txn, cohort):
    """......"""
    return y

# %% [markdown]
# # Start

# %%
#  label

cohort = datetime(2024, 2, 1)

# step 1
demo = demo[demo['pos_dt']==cohort][['user_id']]

# step 2
since = cohort
until = cohort+relativedelta(months=1)-relativedelta(days=1)
print(f"{since}-----{until}")
txn_data = cc_txn[cc_txn["pos_dt"].between(since, until)]



# step 3
cnt_txn = txn_data.groupby("user_id").agg(txn_cnt=("txn_amt", 'count'))

# step 4
label = demo.merge(cnt_txn, on='user_id', how='left').fillna(0)
label['is_churn'] = (label['txn_cnt']==0) *1
label = label[['user_id', 'is_churn']]

# step 5
label['cohort'] = cohort
y =label

# %% [markdown]
# # run

# %%
#  label

cohort = datetime(2024, 2, 1)
cohort
# Out:
# datetime.datetime(2024, 2, 1, 0, 0)

# %%
# step 1
demo = demo[demo['pos_dt']==cohort]
demo
# Out:
#     user_id    income  age  tenure    province   segment     pos_dt
# 50        1   35000.0   30       3     Bangkok    middle 2024-02-01
# 51        2  100000.0   28       7     Bangkok  affluent 2024-02-01
# 52        3   50000.0   50      15  Nonthaburi    middle 2024-02-01
# 53        4   15000.0   52      18         NaN       low 2024-02-01
# 54        5       NaN   21       2      Phuket  affluent 2024-02-01

# %%
# step 2
since = cohort
until = cohort+relativedelta(months=1)-relativedelta(days=1)
print(f"{since}-----{until}")
txn_data = cc_txn[cc_txn["pos_dt"].between(since, until)]
txn_data
# Out:
# 2024-02-01 00:00:00-----2024-02-29 00:00:00
#      user_id     pos_dt       txn_amt   category
# 12         4 2024-02-09   1013.350129  brandname
# 30         5 2024-02-17  13465.358903   gasoline
# 31         5 2024-02-18   3197.862695   gasoline
# 35         3 2024-02-09   1683.225126       food
# 40         5 2024-02-01   7237.447354   gasoline
# ..       ...        ...           ...        ...
# 619        3 2024-02-26   3473.007475   gasoline
# 626        4 2024-02-19   1137.072485   gasoline
# 628        3 2024-02-06   3582.170687   gasoline
# 631        4 2024-02-24    915.777524       food
# 635        3 2024-02-21   5420.344183  brandname
#
# [82 rows x 4 columns]

# %%
# step 3
cnt_txn = txn_data.groupby("user_id").agg(txn_cnt=("txn_amt", 'count'))
cnt_txn
# Out:
#          txn_cnt
# user_id
# 1             18
# 3             29
# 4             12
# 5             23

# %%
# step 4
label = demo.merge(cnt_txn, on='user_id', how='left').fillna(0)
label['is_churn'] = (label['txn_cnt']==0) *1
label = label[['user_id', 'is_churn']]
label
# Out:
#    user_id  is_churn
# 0        1         0
# 1        2         1
# 2        3         0
# 3        4         0
# 4        5         0

# %%
# step 5
label['cohort'] = cohort
y=label
y
# Out:
#    user_id  is_churn     cohort
# 0        1         0 2024-02-01
# 1        2         1 2024-02-01
# 2        3         0 2024-02-01
# 3        4         0 2024-02-01
# 4        5         0 2024-02-01

# %%
# build function

# %%
def pipeline_label(demo, txn, cohort):
  demo = demo[demo['pos_dt']==cohort]
  since = cohort
  until = cohort+relativedelta(months=1)-relativedelta(days=1)
  print(f"{since}-----{until}")
  txn_data = cc_txn[cc_txn["pos_dt"].between(since, until)]
  txn_data

  # step 3
  cnt_txn = txn_data.groupby("user_id").agg(txn_cnt=("txn_amt", 'count'))
  cnt_txn

  # step 4
  label = demo.merge(cnt_txn, on='user_id', how='left').fillna(0)
  label['is_churn'] = (label['txn_cnt']==0)*1
  label = label[['user_id', 'is_churn']]
  label

  # step 5
  label['cohort'] = cohort
  y=label
  y
  return y

# %%
pipeline_label(demo=demo, txn=cc_txn, cohort=datetime(2024, 1, 1))
# Out:
# 2024-01-01 00:00:00-----2024-01-31 00:00:00
#    user_id  is_churn     cohort
# 0        1         0 2024-01-01
# 1        2         0 2024-01-01
# 2        3         0 2024-01-01
# 3        4         0 2024-01-01
# 4        5         0 2024-01-01

# %% [markdown]
# # Features

# %%
def filter_txn_by_cohort(txn, cohort, duration=6):
    since = cohort - relativedelta(months=duration)
    until = cohort - relativedelta(days=1)
    print(f"{since}-----{until}")
    txn_data = txn[txn["pos_dt"].between(since, until)]
    return txn_data


def agg_stats(txn, cohort, duration):
    print('calculate stats')
    txn_m = filter_txn_by_cohort(txn=txn, cohort=cohort, duration=duration)
    feats = txn_m.groupby("user_id").agg(
        txn_cnt=("txn_amt", 'count'),
        sum_amt=("txn_amt", 'sum'),
        max_amt=("txn_amt", 'max'),
        min_amt=("txn_amt", 'min'),
    ).reset_index()

    feats = feats.rename(columns={"txn_cnt": f"txn_cnt_l{duration}m",
                                  "sum_amt": f"sum_amt_l{duration}m",
                                  "max_amt": f"max_amt_l{duration}m",
                                  "min_amt": f"min_amt_l{duration}m",}
                        )

    feats[f"txn_cnt_per_month_l{duration}m"] = feats[f"txn_cnt_l{duration}m"]/duration
    feats[f"sum_amt_per_month_l{duration}m"] = feats[f"sum_amt_l{duration}m"]/duration
    return feats

# %%
def pipeline_features(demo, txn, cohort):

    # step1
    # filter demo.
    # step3
    # demo features


    demo = demo[demo['pos_dt']==cohort-relativedelta(months=1)]
    demo = demo[['user_id', 'income', 'age', 'tenure', 'province', 'segment']]

    # step2
    # filter cc_txn


    txn_agg_1 = agg_stats(txn=txn, cohort=cohort, duration=1)
    txn_agg_3 = agg_stats(txn=txn, cohort=cohort, duration=3)
    txn_agg_6 = agg_stats(txn=txn, cohort=cohort, duration=6)


    # join together

    features = (
            demo.merge(txn_agg_1, on="user_id", how="left")
            .merge(txn_agg_3, on="user_id", how="left")
            .merge(txn_agg_6, on="user_id", how="left")
    )

    # additional create features

    # build more feature ex

    features['txn_cnt_trend'] = features['txn_cnt_l1m']/features['txn_cnt_per_month_l6m']
    features['sum_amt_trend'] = features['sum_amt_l1m']/features['sum_amt_per_month_l6m']
    features['sum_amt_per_income'] = features['sum_amt_l1m']/features['income']

    # step 6
    # add cohort

    features['cohort'] = cohort
    features = features[
            [
                "user_id",
                "cohort",
                'age', 'segment', 'tenure', 'income',
                "txn_cnt_l1m",
                "txn_cnt_l3m",
                "txn_cnt_l6m",
                "sum_amt_l1m",
                "sum_amt_l3m",
                "sum_amt_l6m",
                "min_amt_l3m",
                "max_amt_l3m",
                "min_amt_l6m",
                "max_amt_l6m",
                "txn_cnt_per_month_l6m",
                "sum_amt_per_month_l6m",
                "txn_cnt_trend",
                "sum_amt_trend",
            ]
        ]

    X = features

    return X

# %%
pipeline_features(demo=demo, txn=cc_txn, cohort=datetime(2024, 1, 1))
# Out:
# calculate stats
# 2023-12-01 00:00:00-----2023-12-31 00:00:00
# calculate stats
# 2023-10-01 00:00:00-----2023-12-31 00:00:00
# calculate stats
# 2023-07-01 00:00:00-----2023-12-31 00:00:00
#    user_id     cohort  age   segment  tenure    income  txn_cnt_l1m  \
# 0        1 2024-01-01   30    middle       3   35000.0           26
# 1        2 2024-01-01   28  affluent       7  100000.0           28
# 2        3 2024-01-01   50    middle      15   50000.0           13
# 3        4 2024-01-01   52       low      18   15000.0           29
# 4        5 2024-01-01   21  affluent       2       NaN           27
#
#    txn_cnt_l3m  txn_cnt_l6m  sum_amt_l1m  sum_amt_l3m  sum_amt_l6m  \
# 0           64           89      60000.0     140000.0     191000.0
# 1           64           97      50000.0     150000.0     260000.0
# 2           56           97      40000.0     150000.0     365000.0
# 3           50           98      10000.0      30000.0      50000.0
# ...

# %%
def gen_Xy(demo, txn, cohort):
  X = pipeline_features(demo, txn , cohort)
  y = pipeline_label(demo, txn , cohort)
  Xy = X.merge(y, on=['user_id', 'cohort'])
  return Xy

# %%
gen_Xy(demo=demo, txn=cc_txn, cohort=datetime(2024, 2, 1))
# Out:
# calculate stats
# 2024-01-01 00:00:00-----2024-01-31 00:00:00
# calculate stats
# 2023-11-01 00:00:00-----2024-01-31 00:00:00
# calculate stats
# 2023-08-01 00:00:00-----2024-01-31 00:00:00
# 2024-02-01 00:00:00-----2024-02-29 00:00:00
#    user_id     cohort  age   segment  tenure    income  txn_cnt_l1m  \
# 0        1 2024-02-01   30    middle       3   35000.0           17
# 1        2 2024-02-01   28  affluent       7  100000.0           20
# 2        3 2024-02-01   50    middle      15   50000.0           11
# 3        4 2024-02-01   52       low      18   15000.0           21
# 4        5 2024-02-01   21  affluent       2       NaN           11
#
#    txn_cnt_l3m  txn_cnt_l6m  sum_amt_l1m  sum_amt_l3m  sum_amt_l6m  \
# 0           53          106      70000.0     160000.0     261000.0
# 1           60          117      50000.0     150000.0     310000.0
# 2           50          108      50000.0     190000.0     415000.0
# ...

# %%
gen_Xy(demo=demo, txn=cc_txn, cohort=datetime(2024, 1, 1))

gen_Xy(demo=demo, txn=cc_txn, cohort=datetime(2024, 2, 1))

gen_Xy(demo=demo, txn=cc_txn, cohort=datetime(2024, 3, 1))

# %% [markdown]
# # Key

# %%
def pipeline_label(demo, txn, cohort):

    print('start build labels')
    since = cohort
    until = cohort + relativedelta(months=1) - relativedelta(days=1)
    print(f"{since}-----{until}")
    txn_data = txn[txn["pos_dt"].between(since, until)]

    demo = demo[demo['pos_dt']==cohort][['user_id']]

    cnt_txn = txn_data.groupby("user_id").agg(txn_cnt=("txn_amt", 'count'))
    label = demo.merge(cnt_txn, on='user_id', how='left').fillna(0)
    label['is_churn'] = (label['txn_cnt']==0)*1
    label = label[['user_id', 'is_churn']]
    label['cohort'] = cohort
    return label

# %%
pipeline_label(demo=demo, txn=cc_txn, cohort=datetime(2024, 2, 1))

# %%
def filter_txn_by_cohort(txn, cohort, duration=6):
    since = cohort - relativedelta(months=duration)
    until = cohort - relativedelta(days=1)
    print(f"{since}-----{until}")
    txn_data = txn[txn["pos_dt"].between(since, until)]
    return txn_data

# %%
filter_txn_by_cohort(txn=cc_txn, cohort=datetime(2024, 2, 1), duration=6)

# %%
def agg_stats(txn, cohort, duration):
    print('calculate stats')
    txn_m = filter_txn_by_cohort(txn=txn, cohort=cohort, duration=duration)
    feats = txn_m.groupby("user_id").agg(
        txn_cnt=("txn_amt", 'count'),
        sum_amt=("txn_amt", 'sum'),
        max_amt=("txn_amt", 'max'),
        min_amt=("txn_amt", 'min'),
    ).reset_index()

    feats = feats.rename(columns={"txn_cnt": f"txn_cnt_l{duration}m",
                                  "sum_amt": f"sum_amt_l{duration}m",
                                  "max_amt": f"max_amt_l{duration}m",
                                  "min_amt": f"min_amt_l{duration}m",}
                        )

    feats[f"txn_cnt_per_month_l{duration}m"] = feats[f"txn_cnt_l{duration}m"]/duration
    feats[f"sum_amt_per_month_l{duration}m"] = feats[f"sum_amt_l{duration}m"]/duration
    return feats


def agg_stats_in_category(txn, cohort, duration, category):
    print(f'calculate stats in {category}')
    txn_m = filter_txn_by_cohort(txn=txn, cohort=cohort, duration=duration)
    txn_m = txn_m[txn_m['category']==category]
    feats = txn_m.groupby("user_id").agg(
        txn_cnt=("txn_amt", 'count'),
        sum_amt=("txn_amt", 'sum'),
    ).reset_index()

    feats = feats.rename(columns={"txn_cnt": f"txn_cnt_{category}_l{duration}m",
                                  "sum_amt": f"sum_amt_{category}_l{duration}m"}
                        )

    return feats

# %%
agg_stats(txn=cc_txn, cohort=datetime(2024, 2, 1), duration=1)

# %%
agg_stats_in_category(txn=cc_txn, cohort=datetime(2024, 2, 1), duration=6, category='gasoline')

# %%
def pipeline_features(demo, txn, cohort):
    print('start build features')
    demo = demo[demo['pos_dt']==cohort]
    demo = demo[['user_id', 'income', 'age', 'tenure', 'province', 'segment']]

    txn_agg_1 = agg_stats(txn=txn, cohort=cohort, duration=1)
    txn_agg_3 = agg_stats(txn=txn, cohort=cohort, duration=3)
    txn_agg_6 = agg_stats(txn=txn, cohort=cohort, duration=6)
    txn_gasoline_agg_3 = agg_stats_in_category(txn=txn, cohort=cohort, duration=3, category='gasoline')

    features = (
        demo.merge(txn_agg_1, on="user_id", how="left")
        .merge(txn_agg_3, on="user_id", how="left")
        .merge(txn_agg_6, on="user_id", how="left")
        .merge(txn_gasoline_agg_3, on="user_id", how="left")
    )


    features['txn_cnt_trend'] = features['txn_cnt_l1m']/features['txn_cnt_per_month_l6m']
    features['sum_amt_trend'] = features['sum_amt_l1m']/features['sum_amt_per_month_l6m']
    features['cohort'] = cohort
    features = features[
        [
            "user_id",
            "cohort",
            'age', 'segment', 'tenure', 'income',

            "txn_cnt_l1m",
            "txn_cnt_l3m",
            "txn_cnt_l6m",

            "sum_amt_l1m",
            "sum_amt_l3m",
            "sum_amt_l6m",


            "min_amt_l3m",
            "max_amt_l3m",
            "min_amt_l6m",
            "max_amt_l6m",

            "txn_cnt_per_month_l6m",
            "sum_amt_per_month_l6m",

            "txn_cnt_gasoline_l3m",
            "sum_amt_gasoline_l3m",

            "txn_cnt_trend",
            "sum_amt_trend",
        ]
    ]

    return features

# %%
pipeline_features(demo=demo, txn=cc_txn, cohort=datetime(2024, 2, 1))

# %%
def gen_Xy(demo, txn, cohort):
    X = pipeline_features(demo, txn, cohort=cohort)
    y = pipeline_label(demo, txn, cohort=cohort)
    Xy = X.merge(y, on=['user_id', 'cohort'])
    return Xy

# %%
gen_Xy(demo=demo, txn=cc_txn, cohort=datetime(2024, 2, 1))
